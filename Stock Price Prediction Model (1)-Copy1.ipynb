# %% [markdown]
# # Project - Stock Price Prediction Model

# %% [markdown]
# In this machine learning project, we will be talking about predicting the returns on stocks. This is a very complex task and has uncertainties. We will develop this project into two parts: First, we will learn how to predict stock price using the LSTM neural network. Then we will build a dashboard using Plotly dash for stock analysis.

# %%
#Importing the Dependencies

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data, wb
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")

# %%
from datetime import datetime
import datetime as dt
start = dt.datetime(2002,1,1)
end = dt.datetime(2022,1,1)

# %%
#Data Collection & Processing

# %%
## Importing Dataset ##
Tata_df = data.DataReader("TATACONSUM.NS",'yahoo',start,end)
#Tata_df = pd.read_csv(r"D:\NSE-Tata-Global-Beverages-Limited\TATACONSUM.NS.csv")

# %%
# getting some statistical measures about the data
Tata_df.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  4976.000000  4976.000000  4976.000000  4976.000000  4.976000e+03
# mean    161.432124   156.452106   159.031362   158.800569  2.303616e+06
# std     165.420641   161.315284   163.517969   163.308458  2.481842e+06
# min      14.950000    14.090000    14.090000    14.765000  0.000000e+00
# 25%      73.352501    71.010002    72.359999    72.118752  9.801730e+05
# 50%     116.000000   112.000000   113.850002   114.075001  1.656440e+06
# 75%     162.399994   157.250000   159.724998   159.449997  2.831626e+06
# max     889.000000   877.599976   885.000000   882.099976  6.355124e+07
#
#          Adj Close
# count  4976.000000
# mean    147.401409
# std     166.307779
# min      10.403296
# 25%      56.375359
# 50%      97.894203
# 75%     144.234833
# max     882.099976

# %%
# printing the first 5 rows of the dataframe
Tata_df.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2002-01-01  17.500000  16.799999  17.350000  16.905001  722730.0  11.417471
# 2002-01-02  17.184999  16.799999  17.000000  16.850000  290270.0  11.380326
# 2002-01-03  17.200001  16.870001  16.955000  17.059999  360580.0  11.522157
# 2002-01-04  17.299999  16.809999  17.270000  16.955000  682690.0  11.451240
# 2002-01-07  17.750000  17.049999  17.200001  17.400000  840670.0  11.751791

# %%
# printing the last 5 rows of the dataframe
Tata_df.tail()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-12-27  724.500000  706.750000  710.000000  718.500000   691930.0
# 2021-12-28  729.549988  719.400024  722.299988  726.950012   819253.0
# 2021-12-29  728.900024  720.000000  728.000000  726.650024   783940.0
# 2021-12-30  737.849976  725.299988  729.000000  728.000000  2230935.0
# 2021-12-31  745.000000  729.049988  730.000000  743.450012   865277.0
#
#              Adj Close
# Date
# 2021-12-27  718.500000
# 2021-12-28  726.950012
# 2021-12-29  726.650024
# 2021-12-30  728.000000
# 2021-12-31  743.450012

# %%
#Handling the Missing values

# %%
## Checking for null values ##
Tata_df.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# drop the null values from the dataframe
Tata_df = Tata_df.dropna()

# %%
(Tata_df['Volume'] == 0).sum()
# Out:
# 34

# %%
Tata_df['Volume'] = Tata_df ['Volume'].replace({0:np.nan})

# %%
Tata_df.isnull().sum()
# Out:
# High          0
# Low           0
# Open          0
# Close         0
# Volume       34
# Adj Close     0
# dtype: int64

# %%
Tata_df = Tata_df.dropna()

# %%
Tata_df.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# getting some informations about the data
Tata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4942 entries, 2002-01-01 to 2021-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       4942 non-null   float64
#  1   Low        4942 non-null   float64
#  2   Open       4942 non-null   float64
#  3   Close      4942 non-null   float64
#  4   Volume     4942 non-null   float64
#  5   Adj Close  4942 non-null   float64
# dtypes: float64(6)
# memory usage: 270.3 KB

# %% [markdown]
# ### Data Visualization

# %%
## Analysing the key attributes of our dataset ##

# %%
#Tata_df["Date"]=pd.to_datetime(Tata_df.Date,format="%Y-%m-%d")
#Tata_df.index=Tata_df['Date']

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot 
#Cufflink is also a python library that connects plotly with pandas so that we can create charts directly on data frames.
import cufflinks as cf
#In order to display the plot inside the notebook, you need to initiate plotly’s notebook mode as follows 
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Tata_df['Close'].iplot(kind = 'line',title = 'Close Price History')
# Out:
# <div>                            <div id="5dea29ad-b90d-405d-9b2b-530e9796f0c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("5dea29ad-b90d-405d-9b2b-530e9796f0c4")) {                    Plotly.newPlot(                        "5dea29ad-b90d-405d-9b2b-530e9796f0c4",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Close","text":"","x":["2002-01-01","2002-01-02","2002-01-03","2002-01-04","2002-01-07","2002-01-08","2002-01-09","2002-01-10","2002-01-11","2002-01-14","2002-01-15","2002-01-16","2002-01-17","2002-01-18","2002-01-21","2002-01-22","2002-01-23","2002-01-24","2002-01-25","2002-01-28","2002-01-29","2002-01-30","2002-01-31","2002-02-01","2002-02-04","2002-02-05","2002-02-06","2002-02-07","2002-02-08","2002-02-11","2002-02-12","2002-02-13","2002-02-14","2002-02-15","2002-02-18","2002-02-19","2002-02-20","2002-02-21","2002-02-22","2002-02-25","2002-02-26","2002-02-27","2002-02-28","2002-03-01","2002-03-04","2002-03-05","2002-03-06","2002-03-07","2002-03-08","2002-03-11","2002-03-12","2002-03-13","2002-03-14","2002-03-15","2002-03-18","2002-03-19","2002-03-20","2002-03-21","2002-03-22","2002-03-26","2002-03-27","2002-03-28","2002-04-01","2002-04-02","2002-04-03","2002-04-04","2002-04-05","2002-04-08","2002-04-09","2002-04-10","2002-04-11","2002-04-12","2002-04-15","2002-04-16","2002-04-17","2002-04-18","2002-04-19","2002-04-22","2002-04-23","2002-04-24","2002-04-25","2002-04-26","2002-04-29","2002-04-30","2002-05-02","2002-05-03","2002-05-06","2002-05-07","2002-05-08","2002-05-09","2002-05-10","2002-05-13","2002-05-14","2002-05-15
# %%
## Overall look at the average daily return using a histogram.(Using seaborn) ##

# %%
plt.figure(figsize=(12, 7))
Tata_df['Daily Return'].hist(bins=50)
plt.ylabel('Daily Return')
plt.title('Tata Consumer Products Ltd')
# Out:
# Text(0.5, 1.0, 'Tata Consumer Products Ltd')

# %%
sns.jointplot(data=Tata_df['Daily Return'], kind='scatter', color='seagreen')

# %%
#From above figure we can assume that the daily return follows Random Walk Theory

# %%
#Dividing training and testing data in 70:30

# %%
data_training = pd.DataFrame(Tata_df['Adj Close'][0:int(len(Tata_df)*0.70)])
data_testing = pd.DataFrame(Tata_df['Adj Close'][int(len(Tata_df)*0.70): int(len(Tata_df))])

# %%
print(data_training.shape)
print(data_testing.shape)
# Out:
# (3459, 1)
# (1483, 1)

# %%
#Normalizing the training dataset using MinMaxScaler(the MinMaxScaler estimator will fit on the training dataset and the same estimator will be used to transform both training and the test dataset)

# %%
Scaler = MinMaxScaler(feature_range = (0,1))

# %%
data_training_array = Scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.00689048],
#        [0.00663811],
#        [0.00760173],
#        ...,
#        [0.83332989],
#        [0.81983702],
#        [0.84776398]])

# %%
data_training_array.shape
# Out:
# (3459, 1)

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (3359, 100, 1)

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True,
              input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimiz
# Epoch 41/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.0026
# Epoch 42/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.0026
# Epoch 43/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.0026
# Epoch 44/50
# 105/105 [==============================] - 14s 129ms/step - loss: 0.0027
# Epoch 45/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.0025
# Epoch 46/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.0024
# Epoch 47/50
# 105/105 [==============================] - 14s 131ms/step - loss: 0.0026
# Epoch 48/50
# 105/105 [==============================] - 14s 135ms/step - loss: 0.0025
# Epoch 49/50
# 105/105 [==============================] - 14s 134ms/step - loss: 0.0026
# Epoch 50/50
# 105/105 [==============================] - 14s 130ms/step - loss: 0.0026

# %% [markdown]
# lstm_model.save("saved_model.h5")

# %%
model.save("saved_model.h5")

# %%
data_testing.head()
# Out:
#              Adj Close
# Date
# 2015-12-31  135.042786
# 2016-01-01  135.227524
# 2016-01-04  132.733597
# 2016-01-05  137.028732
# 2016-01-06  134.165298

# %%
data_training.tail(100)
# Out:
#              Adj Close
# Date
# 2015-08-03  130.101089
# 2015-08-04  132.364120
# 2015-08-05  131.301834
# 2015-08-06  132.779785
# 2015-08-07  131.117111
# ...                ...
# 2015-12-23  131.163330
# 2015-12-24  133.749649
# 2015-12-28  133.056885
# 2015-12-29  131.070938
# 2015-12-30  135.181366
#
# [100 rows x 1 columns]

# %%
past_100_days = data_training.tail(100)

# %%
final_df = past_100_days.append(data_testing, ignore_index = True)

# %%
final_df.head()
# Out:
#     Adj Close
# 0  130.101089
# 1  132.364120
# 2  131.301834
# 3  132.779785
# 4  131.117111

# %%
input_data = Scaler.fit_transform(final_df)

# %%
input_data
# Out:
# array([[0.04481839],
#        [0.04769287],
#        [0.04634357],
#        ...,
#        [0.802549  ],
#        [0.80426372],
#        [0.82388818]])

# %%
input_data.shape
# Out:
# (1583, 1)

# %%
x_test = []
y_test = []

# %%
for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100: i])
    y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1483, 100, 1)
# (1483,)

# %%
#Predictions

# %%
y_predicted = model.predict(x_test)

# %%
y_predicted.shape
# Out:
# (1483, 1)

# %%
y_test
# Out:
# array([0.05109529, 0.05132994, 0.04816218, ..., 0.802549  , 0.80426372,
#        0.82388818])

# %%
y_predicted
# Out:
# array([[0.09193143],
#        [0.09255436],
#        [0.09320122],
#        ...,
#        [0.7302531 ],
#        [0.73281205],
#        [0.736049  ]], dtype=float32)

# %%
Scaler.scale_
# Out:
# array([0.00127019])

# %%
scale_factor = 1/0.00127019
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = 'Original Price')
plt.plot(y_predicted, 'r', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
